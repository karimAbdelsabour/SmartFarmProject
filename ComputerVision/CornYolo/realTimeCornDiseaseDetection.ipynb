# %%
import cv2
from ultralytics import YOLO

model = YOLO("best.pt") 


cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video source.")
    exit()

while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Could not read frame.")
        break
    

    results = model(frame) 


    annotated_frame = results[0].plot()
    

    cv2.imshow("YOLOv8 Real-Time Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 73.4ms
# Speed: 12.4ms preprocess, 73.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 62.9ms
# Speed: 3.7ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 2 CornNorthenLeafBlights, 64.2ms
# Speed: 4.1ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 79.6ms
# Speed: 4.0ms preprocess, 79.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 50.7ms
# Speed: 0.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 52.8ms
# Speed: 5.1ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 54.8ms
# Speed: 0.0ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 49.0ms
# Speed: 2.7ms preprocess, 49.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 50.0ms
# Speed: 4.8ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 58.0ms
# Speed: 0.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 48.0ms
# Speed: 3.1ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 56.6ms
# Speed: 2.3ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 57.2ms
# Speed: 0.0ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 50.7ms
# Speed: 0.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 52.1ms
# Speed: 0.0ms preprocess, 52.1ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 56.7ms
# Speed: 3.7ms preprocess, 56.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 55.3ms
# Speed: 2.2ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 50.4ms
# Speed: 0.0ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 53.6ms
# Speed: 0.0ms preprocess, 53.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 56.4ms
# Speed: 2.1ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 44.9ms
# Speed: 2.1ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 49.2ms
# Speed: 2.6ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 47.1ms
# Speed: 2.1ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 49.8ms
# Speed: 0.0ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 48.5ms
# Speed: 0.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 53.1ms
# Speed: 0.0ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 59.2ms
# Speed: 3.2ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 47.8ms
# Speed: 0.0ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 46.2ms
# Speed: 3.2ms preprocess, 46.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 52.2ms
# Speed: 0.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 48.2ms
# Speed: 0.0ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 51.7ms
# Speed: 0.0ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 48.4ms
# Speed: 0.0ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 42.9ms
# Speed: 3.1ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 46.9ms
# Speed: 1.6ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 46.2ms
# Speed: 0.0ms preprocess, 46.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 48.6ms
# Speed: 3.0ms preprocess, 48.6ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 39.6ms
# Speed: 1.9ms preprocess, 39.6ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 36.8ms
# Speed: 2.4ms preprocess, 36.8ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 51.6ms
# Speed: 0.0ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 57.8ms
# Speed: 0.0ms preprocess, 57.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 43.9ms
# Speed: 2.8ms preprocess, 43.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 45.5ms
# Speed: 2.6ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornNorthenLeafBlight, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 44.7ms
# Speed: 2.1ms preprocess, 44.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 45.6ms
# Speed: 3.2ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornCommonRust, 49.1ms
# Speed: 0.0ms preprocess, 49.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornCommonRust, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornCommonRust, 50.0ms
# Speed: 3.2ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornCommonRust, 48.4ms
# Speed: 2.2ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 48.5ms
# Speed: 1.7ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornCommonRust, 39.7ms
# Speed: 0.8ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 53.2ms
# Speed: 4.3ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 46.7ms
# Speed: 3.3ms preprocess, 46.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 53.1ms
# Speed: 3.3ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 50.8ms
# Speed: 2.1ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornNorthenLeafBlight, 44.1ms
# Speed: 2.4ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCommonRust, 1 CornNorthenLeafBlight, 58.8ms
# Speed: 2.9ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 56.8ms
# Speed: 0.8ms preprocess, 56.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornNorthenLeafBlight, 51.2ms
# Speed: 0.0ms preprocess, 51.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 43.2ms
# Speed: 0.0ms preprocess, 43.2ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 56.7ms
# Speed: 2.2ms preprocess, 56.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 54.4ms
# Speed: 0.0ms preprocess, 54.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 51.2ms
# Speed: 3.2ms preprocess, 51.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCommonRust, 1 CornNorthenLeafBlight, 49.8ms
# Speed: 3.0ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 CornCercosporaLeafSpots, 1 CornCommonRust, 1 CornNorthenLeafBlight, 47.1ms
# Speed: 3.4ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCommonRust, 1 CornNorthenLeafBlight, 54.9ms
# Speed: 0.0ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 43.5ms
# Speed: 4.2ms preprocess, 43.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 50.2ms
# Speed: 2.9ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 52.0ms
# Speed: 0.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCercosporaLeafSpot, 1 CornCommonRust, 1 CornNorthenLeafBlight, 51.9ms
# Speed: 3.0ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornCommonRust, 1 CornNorthenLeafBlight, 51.9ms
# Speed: 0.0ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 63.4ms
# Speed: 7.3ms preprocess, 63.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 55.0ms
# Speed: 2.7ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 53.1ms
# Speed: 2.6ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 CornNorthenLeafBlight, 49.9ms
